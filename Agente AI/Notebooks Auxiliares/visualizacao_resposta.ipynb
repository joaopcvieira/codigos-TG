# %%
import pandas as pd
import numpy as np

# Le do arquivo txt a matriz A
# Usar delimitador de um único caractere. Espaços após a vírgula são ignorados automaticamente.
A = np.loadtxt('../matriz_dematel.txt', delimiter=',')

A



df_fatores = pd.read_csv('../inputs/fatores.csv')
fatores = df_fatores['fator'].tolist()

# Verifica consistência entre número de fatores e dimensão da matriz A
if A.shape[0] != len(fatores):
    raise ValueError(f'Tamanho da matriz A ({A.shape[0]}) difere do número de fatores ({len(fatores)}).')

# Cria o DataFrame rotulado diretamente a partir de A
df_esqueleto = pd.DataFrame(A, index=fatores, columns=fatores)
df_esqueleto
# Out:
#                                                     Documentação de Projeto  \
# Documentação de Projeto                                                 0.0
# Experiência da Equipe                                                   7.0
# Qualidade da Comunicação                                                7.0
# Disponibilidade de Tempo                                                7.0
# Orçamento Disponível                                                    7.0
# Volume da Câmara                                                        3.0
# Razão de mistura O/F e controle de vazão do oxi...                      5.0
# Temperatura do Oxigênio                                                 0.0
# Massa de Parafina                                                       3.0
# Acabamento Superficial do Grão e pureza da para...                      2.0
# Temperatura Ambiente                                                    2.0
# ...

# %%
import pandas as pd
import os

print(os.listdir('..'))

df_fatores = pd.read_csv('../inputs/Fatores.csv')
df_fatores
# Out:
# ['matriz_dematel.txt', '.DS_Store', 'out', 'resultado TG1', '__pycache__', 'Teste.py', 'log.md', 'links', '.env', 'dematel_graph.png', 'functions', 'Notebooks Auxiliares', 'main.py', 'inputs']
#    artigo                                              fator  \
# 0       a                            Documentação de Projeto
# 1       a                              Experiência da Equipe
# 2       a                           Qualidade da Comunicação
# 3       a                           Disponibilidade de Tempo
# 4       o                               Orçamento Disponível
# 5       o                                   Volume da Câmara
# 6       a  Razão de mistura O/F e controle de vazão do ox...
# 7       a                            Temperatura do Oxigênio
# 8       a                                  Massa de Parafina
# 9       o  Acabamento Superficial do Grão e pureza da par...
# 10      a                               Temperatura Ambiente
# ...
